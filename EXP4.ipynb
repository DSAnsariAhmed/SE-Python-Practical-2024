# %%
with open ("Sample.txt", "a") as file:
  file.write ("This is my new data file.\n")
  file.write("This is some data in it.\n")
with open ("Sample.txt", "r") as file:
  contents = file.read ()
with open("Sample.txt", "a") as file:
  file.write("Written using write.\n")
  file.write("Adding to file data.\n")
with open ("Sample.txt", "r") as file:
  contents = file.read ()
  print (contents)
with open ("Sample.txt", "w") as file:
  file.write ("This is some replacement data.\n")
with open ("Sample.txt", "r") as file: contents = file.read ()
print(contents)
import os
os.remove ("Sample.txt")
with open ("newfile.txt", "w") as file:
  file.write ("Some data in a new file.\n")
with open ("newfile.txt", "r") as file:
  contents = file.read()
print(contents)
print(contents)
# Out:
# This is my new data file.
# This is some data in it.
# Written using write.
# Adding to file data.
#
# This is some replacement data.
#
# Some data in a new file.
#
# Some data in a new file.
