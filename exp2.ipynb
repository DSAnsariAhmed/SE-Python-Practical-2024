# %%
# !python --version
print()
# Out:
# Python 3.10.12

# %%
("Hello world")
# Out:
# 'Hello world'

# %%
print(a)
# Out:
# 4

# %%
type(a)
# Out:
# str

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
myvar="Hohn"
_myvar="Hohn"
my_var="hojn"

# %%
x,y,z="Orange","cherry","banana"

# %%
print(x)
print(y)
print(z)
# Out:
# Orange
# cherry
# banana

# %%
x=y=z="Orange"

# %%
print(x)
print(y)
print(z)
# Out:
# Orange
# Orange
# Orange

# %%
fruits=["Orange","cherry","banana"]
x,y,z=fruits
print(x)
print(y)
print(z)
# Out:
# Orange
# cherry
# banana

# %%
x="Python"

def myfunc():
  print(x,"is awesome")

myfunc()
# Out:
# Python is awesome

# %%
x="Fantastic"

def myfunc():
  x="Python"
  print(x,"is awesome")

myfunc()
print(x)
# Out:
# Python is awesome
# Fantastic

# %%
def myfunc():
  global x
  x="Python"
myfunc()
print(x,"is awesome")
# Out:
# Python is awesome

# %%
x="Awesome"
def myfunc():
  global x
  x="Python"
myfunc()
print(x,"is awesome")
# Out:
# Python is awesome
