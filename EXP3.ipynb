# %%
# define a class
class Bike:
  name = ""
  gear = 0
bike1 = Bike()
# create object of class bike1 = Bike()
# access attributes and assign new values
bike1.gear= 11
bike1.name = "Mountain Bike"
print(f"Name: {bike1.name}, Gears: {bike1.gear} ")
# Out:
# Name: Mountain Bike, Gears: 11

# %%
def greet(name):
  print("Hello, "+name+ "!" ) # Call the function
greet("Jack")
greet("Jil")
# Out:
# Hello, Jack!
# Hello, Jil!
