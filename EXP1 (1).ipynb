# %%
name="Mohd Ahmed"
print("My name is "+name)
# Out:
# My name is Mohd Ahmed

# %%
#String: Surrounded by either single quotation marks, or double quotation marks.
my_string = "Hi Ahmed, this is me!!"
print(my_string[0])
print(my_string[7])
print(my_string[0:9])
# Out:
# H
# d
# Hi Ahmed,

# %%
#List: store multiple items in a single variable.
#One of 4 built-in data types in Python.

# %%
fruits=["apple","banana","cherry"]
print(fruits)
fruits.append("orange")
print(fruits)
fruits.remove("banana")
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']
# ['apple', 'banana', 'cherry', 'orange']
# ['apple', 'cherry', 'orange']

# %%
#Dictionary: used to store data values in key:value pairs.
#Collection which is ordered, changeable and do not allow duplicates.

# %%
person={'name':'ahmed','age':19,'city':'Mumbai'}
print(person)
del person ['city']
print (person)
# Out:
# {'name': 'ahmed', 'age': 19, 'city': 'Mumbai'}
# {'name': 'ahmed', 'age': 19}

# %%
#tuple: Tuples are used to store multiple items in a single variable.
#Built in data type. Is ordered and unchangeable.

# %%
numbers=(1,2,3)
print(numbers)
print (numbers[2])
print (numbers[0:2])
# Out:
# (1, 2, 3)
# 3
# (1, 2)
